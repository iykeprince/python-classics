# %% [markdown]
# # Statistics Module
#
# ### Provide functions for mathematical and statistical analysis of numerical data

# %%
import statistics

# %%
data=[23,45,67,78,78,89,45]

# %%
statistics.mode(data)
# Out:
# 45

# %%
statistics.mean(data)
# Out:
# 60.714285714285715

# %%
statistics.median(data)
# Out:
# 6

# %%
statistics.variance(data)
# Out:
# 877.4545454545455
