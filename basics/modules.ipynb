# %% [markdown]
# ## Modules
# #### Files containing python definition and statements, naming as .py.

# %% [markdown]
# ## Packages
# #### Ways to organize and group related modules. directory containing __init__.py file.

# %%
import math
print(math.sqrt(216))
# Out:
# 14.696938456699069

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
#Importing specific functions or variables
from math import pi, pow

# %%
pi
# Out:
# 3.141592653589793

# %%
pow(3,4)
# Out:
# 81.0

# %%
#Aliasing Modules:
import numpy as np

# %% [markdown]
# ## Custom Module

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import module.area
#
# ModuleNotFoundError: No module named 'module'
