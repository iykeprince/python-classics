# %% [markdown]
# # Tuple
#
# Creating Tuples, enclose parenthesis-() on using TUPLE function

# %%
user_info=('ASH','FORTRAININGPURPOSE101@EMAIL.COM','2026-04-07')

# %%
print("username:",user_info[0])
# Out:
# username: ASH

# %%
print("Email ID:", user_info[1])
# Out:
# Email ID: FORTRAININGPURPOSE101@EMAIL.COM

# %%
blog_information=(202, "Course for Deep Python Series", 3455, "2026-01-01")

# %%
print("Viewers", blog_information[2])
# Out:
# Viewers 3455

# %% [markdown]
# #### Mixed datatypes including number, string, integer etc are all supported in TUPLE

# %%
# Access Tuple

# Negative indexing is supported
blog_information[-1]
# Out:
# '2026-01-01'

# %%
blog_information[1:]
# Out:
# ('Course for Deep Python Series', 3455, '2026-01-01')

# %%
blog_information[:-1]
# Out:
# (202, 'Course for Deep Python Series', 3455)

# %%
blog_information[1:-1]
# Out:
# ('Course for Deep Python Series', 3455)

# %%
blog_information[::-1]
# Out:
# ('2026-01-01', 3455, 'Course for Deep Python Series', 202)

# %% [markdown]
# # Concatenation: How to combine tuples

# %%
num_tup1=(1,3,4,5)
num_tup2=(7,8,9,22)

# %%
total_concatenated=num_tup1+num_tup2
total_concatenated
# Out:
# (1, 3, 4, 5, 7, 8, 9, 22)

# %%
repeated_tup1=num_tup1*2
print(repeated_tup1)
# Out:
# (1, 3, 4, 5, 1, 3, 4, 5)

# %%
tuple1=(12,35,66)

# %% [markdown]
# ## TUPLES ARE IMMUTABLE
# ### You cannot change the values of tuples

# %%
tuple1[1]=44
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 tuple1[1]=44
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Tuple Methods

# %%
mobilenotifications=('newmessagearrive','alertnotification','warning','newmessagearive','newmessagearrive','alertnotification', 'alertnotification','warning')

# %%
mobilenotifications.count('alertnotification')
# Out:
# 3

# %%
mobilenotifications.index("newmessagearrive")
# Out:
# 0

# %% [markdown]
# ## Packing
# #### Assigning multiple values to a tuple

# %%
#Packing:
p1=1,2,"Hi this is ITOnline learning"

# %%
#Unpacking: Assigning multiple tuple values to multiple variables.
a,v,var1=p1

# %%
a
# Out:
# 1

# %%
v
# Out:
# 2

# %%
var1
# Out:
# 'Hi this is ITOnline learning'

# %%
config=("localhost", 8080, 5, 3)
host,port,timeout,retry_limit=config

# %%
host, timeout
# Out:
# ('localhost', 5)

# %%
port
# Out:
# 8080

# %% [markdown]
# ## Nested TUPLE
#
# Tuple can contain other tuple as element to form a nested structure.

# %%
meetings=(
    ("9am", "Conference onboarding"),
    ("11am", "Dashboard reporting")
)

# %%
meetings[1][1]
# Out:
# 'Dashboard reporting'

# %%
mobilenofiction=("blocked555","messengerservice","blocked555","warning","messengerservice")
mobilenofiction.count("blocked555")
# Out:
# 2
