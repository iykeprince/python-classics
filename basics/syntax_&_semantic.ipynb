# %%
# This is commented to print the results for the hello world
"""
THis is multiple lines
where you can talk about sections
"""
print('Hello welcome to IT Online Learning')
# Out:
# Hello welcome to IT Online Learning

# %%
output="the output of the first input", 34+34 \
+43
print(output)
# Out:
# ('the output of the first input', 111)

# %% [markdown]
# Execute Multiple Statements in one Line

# %%
x=78;y=12;z=x+y
print(z)
# Out:
# 90

# %%
empid=3434
empname='Iyke'
height=5.11

# %%
print(type(height))
# Out:
# <class 'float'>

# %% [markdown]
# Dynamic Typing
# This allows you to modify your variable by assigning value of different data-type to it.

# %%
empid='5454'
print(type(empid))
# Out:
# <class 'str'>
