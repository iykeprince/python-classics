# %% [markdown]
# # Custom Module

# %%
from area import circle, rect

# %%
circle(20)
# Out:
# 1256.6370614359173

# %%
rect(6,1)
# Out:
# 14

# %%
from data_utils.calculations import multiply

# %%
multiply(4,6)
# Out:
# 24

# %%
import sys

# %%
import math

# %%
print("math" in sys.modules)
# Out:
# True

# %% [markdown]
# # Key points
# - When we use import module, the python loads and executes all the code in module only once per session
# - python avoid re-executing module on repeated imports by caching
